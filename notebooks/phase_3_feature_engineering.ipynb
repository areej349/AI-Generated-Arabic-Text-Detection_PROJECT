# %% [markdown]
# Features:
#
# 3. Number of digits / C
#
# 24. Number of different punctuation signs /C
#
# 45. Number of adjectives
#
# 66. Number of genitives
#
# 7. Gini Coefficient of Word Frequencies: Measures inequality in  word frequency distribution.

# %%
import pandas as pd
import os

BASE_PATH = r"C:\Users\areej\FinalProject(AI_Generated_Arabic_Text_Detection)\data\processed"

train = pd.read_csv(os.path.join(BASE_PATH, "train_features.csv"))
val   = pd.read_csv(os.path.join(BASE_PATH, "val_features.csv"))
test  = pd.read_csv(os.path.join(BASE_PATH, "test_features.csv"))

total = len(train) + len(val) + len(test)

print(" Dataset Split Summary\n")

print(f"Train samples: {len(train)} ({len(train)/total:.2%})")
print(f"Validation samples: {len(val)} ({len(val)/total:.2%})")
print(f"Test samples: {len(test)} ({len(test)/total:.2%})")

print("\nTotal samples:", total)
# Out:
#  Dataset Split Summary
#
# Train samples: 29358 (70.00%)
# Validation samples: 6291 (15.00%)
# Test samples: 6291 (15.00%)
#
# Total samples: 41940
